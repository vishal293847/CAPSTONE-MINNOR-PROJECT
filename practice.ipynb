# %%
import pandas as pd
import numpy as np
from scipy import stats
planes_df=pd.read_csv('planes.csv')
planes_df.head(5)
# Out:
#   tailnum    year                     type      manufacturer      model  \
# 0  N10156  2004.0  Fixed wing multi engine           EMBRAER  EMB-145XR
# 1  N102UW  1998.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 2  N103US  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 3  N104UW  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 4  N10575  2002.0  Fixed wing multi engine           EMBRAER  EMB-145LR
#
#    engines  seats  speed     engine
# 0        2     55    NaN  Turbo-fan
# 1        2    182    NaN  Turbo-fan
# 2        2    182    NaN  Turbo-fan
# 3        2    182    NaN  Turbo-fan
# 4        2     55    NaN  Turbo-fan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
planes_df.shape
# Out:
# (3322, 9)

# %%
planes_df.describe(include='all').T
# Out:
#                count unique                      top  freq        mean  \
# tailnum         3322   3322                   N999DN     1         NaN
# year          3252.0    NaN                      NaN   NaN  2000.48401
# type            3322      3  Fixed wing multi engine  3292         NaN
# manufacturer    3322     35                   BOEING  1630         NaN
# model           3322    127                  737-7H4   361         NaN
# engines       3322.0    NaN                      NaN   NaN    1.995184
# seats         3322.0    NaN                      NaN   NaN  154.316376
# speed           23.0    NaN                      NaN   NaN  236.782609
# engine          3322      6                Turbo-fan  2750         NaN
#
#                      std     min     25%     50%     75%     max
# tailnum              NaN     NaN     NaN     NaN     NaN     NaN
# year            7.193425  1956.0  1997.0  2001.0  2005.0  2013.0
# ...

# %%
sns.histplot(data=planes_df, x='year',bins=50)
# Out:
# <Axes: xlabel='year', ylabel='Count'>

# %%
sns.histplot(data=planes_df, x='year', kde=True);

# %%
sns.histplot(data=planes_df, x='year', hue='engine', kde=True);

# %%
g = sns.FacetGrid(planes_df, col="engine")
g.map(sns.histplot, "year");

# %%
sns.boxplot(data=planes_df, x='year');

# %%
sns.countplot(data=planes_df, x='engines', hue='type');

# %%
plt.title('Histogram:model')
plt.xlim(0,50)
plt.ylim(0,250)
plt.xlabel('model')
plt.ylabel('engines')
sns.histplot(data=planes_df, x='model', color='red');
